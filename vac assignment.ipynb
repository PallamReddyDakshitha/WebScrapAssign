# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url = "https://www.flipkart.com/samsung-mobile-store?otracker=nmenu_sub_Electronics_0_Samsung"

# %%
allow = requests.get(url)

# %%
print(allow)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(allow.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
mobile_name=soup.select(".s1Q9rs")

# %%
mobile_name
# Out:
# [<a class="s1Q9rs" href="/samsung-galaxy-s21-fe-5g-white-256-gb/p/itm18eb461f16ec8?pid=MOBGE8E7SZZCPXQU&amp;lid=LSTMOBGE8E7SZZCPXQUKPRAIJ&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_723fc2a0-bfd7-49d1-bf87-89fc02d671f4_1_1BUWY8OBA8L9_MC.MOBGE8E7SZZCPXQU&amp;ppt=None&amp;ppn=None&amp;ssid=lf7lxr8x8g0000001653978340254&amp;otracker=clp_pmu_v2_Latest%2BSamsung%2Bmobiles%2B_1_1.productCard.PMU_V2_SAMSUNG%2BGalaxy%2BS21%2BFE%2B5G%2B%2528White%252C%2B256%2BGB%2529_samsung-mobile-store_MOBGE8E7SZZCPXQU_neo%2Fmerchandising_0&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Latest%2BSamsung%2Bmobiles%2B_LIST_productCard_cc_1_NA_view-all&amp;cid=MOBGE8E7SZZCPXQU" rel="noopener noreferrer" target="_blank" title="SAMSUNG Galaxy S21 FE 5G (White, 256 GB)">SAMSUNG Galaxy S21 FE 5G (White, 256 GB)</a>,
# ...

# %%
mobile_list = []
mobile_link = []

# %%
for item in mobile_name:
    mobile_list.append(item.text)
    link = "https://www.flipkart.com/"

# %%
mobile_list
# Out:
# ['SAMSUNG Galaxy S21 FE 5G (White, 256 GB)',
#  'SAMSUNG Galaxy S21 FE 5G (Olive, 256 GB)',
#  'SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)',
#  'SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)',
#  'SAMSUNG S20 FE 5G (Cloud Lavender, 128 GB)',
#  'SAMSUNG Galaxy A73 5G (Awesome Mint, 256 GB)',
#  'SAMSUNG Guru Music 2',
#  'SAMSUNG GT-E1215',
#  'SAMSUNG Guru Music 2',
#  'SAMSUNG Guru Music 2',
#  'SAMSUNG GURU MUSIC 2',
#  'SAMSUNG Guru Music 2',
#  'SAMSUNG Galaxy A03 Core (Black, 32 GB)',
#  'SAMSUNG Galaxy A03 Core (Blue, 32 GB)',
#  'SAMSUNG Galaxy M02 (Red, 32 GB)',
#  'SAMSUNG Galaxy J2 Core (Gold, 8 GB)',
#  'SAMSUNG Galaxy On Nxt (Gold, 16 GB)',
#  'SAMSUNG Galaxy J2 Core (Black, 8 GB)',
#  'SAMSUNG Galaxy F22 (Denim Blue, 64 GB)',
#  'SAMSUNG Galaxy F22 (Denim Blue, 128 GB)',
#  'SAMSUNG Galaxy F22 (Denim Black, 64 GB)',
#  'SAMSUNG Galaxy F22 (Denim Black, 128 GB)',
#  'SAMSUNG Galaxy F12 (Sea Green, 64 GB)',
#  'SAMSUNG Galaxy F12 (Celestial Black, 64 GB)',
# ...

# %%
mobile_price = soup.select("._8VNy32 ._30jeq3")

# %%
mobile_price
# Out:
# [<div class="_30jeq3">₹59,990</div>,
#  <div class="_30jeq3">₹59,990</div>,
#  <div class="_30jeq3">₹16,999</div>,
#  <div class="_30jeq3">₹15,999</div>,
#  <div class="_30jeq3">₹36,499</div>,
#  <div class="_30jeq3">₹49,990</div>,
#  <div class="_30jeq3">₹1,850</div>,
#  <div class="_30jeq3">₹1,496</div>,
#  <div class="_30jeq3">₹2,068</div>,
#  <div class="_30jeq3">₹1,995</div>,
#  <div class="_30jeq3">₹1,995</div>,
#  <div class="_30jeq3">₹1,995</div>,
#  <div class="_30jeq3">₹6,999</div>,
#  <div class="_30jeq3">₹6,999</div>,
#  <div class="_30jeq3">₹9,199</div>,
#  <div class="_30jeq3">₹6,299</div>,
#  <div class="_30jeq3">₹9,499</div>,
#  <div class="_30jeq3">₹6,299</div>,
#  <div class="_30jeq3">₹11,999</div>,
#  <div class="_30jeq3">₹13,999</div>,
#  <div class="_30jeq3">₹11,999</div>,
#  <div class="_30jeq3">₹13,999</div>,
#  <div class="_30jeq3">₹11,499</div>,
#  <div class="_30jeq3">₹11,499</div>,
#  <div class="_30jeq3">₹16,999</div>,
# ...

# %%
price =[]

# %%
for item in mobile_price:
    price.append(item.text)

# %%
price
# Out:
# ['₹59,990',
#  '₹59,990',
#  '₹16,999',
#  '₹15,999',
#  '₹36,499',
#  '₹49,990',
#  '₹1,850',
#  '₹1,496',
#  '₹2,068',
#  '₹1,995',
#  '₹1,995',
#  '₹1,995',
#  '₹6,999',
#  '₹6,999',
#  '₹9,199',
#  '₹6,299',
#  '₹9,499',
#  '₹6,299',
#  '₹11,999',
#  '₹13,999',
#  '₹11,999',
#  '₹13,999',
#  '₹11,499',
#  '₹11,499',
#  '₹16,999',
#  '₹16,999',
#  '₹15,999',
#  '₹15,999',
#  '₹15,999',
#  '₹17,035']

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
mobile = pd.DataFrame(mobile_name,columns=["Mobile_name"])

# %%
mobile["price"] = price

# %%
mobile
# Out:
#                                      Mobile_name    price
# 0       SAMSUNG Galaxy S21 FE 5G (White, 256 GB)  ₹59,990
# 1       SAMSUNG Galaxy S21 FE 5G (Olive, 256 GB)  ₹59,990
# 2   SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)  ₹16,999
# 3   SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)  ₹15,999
# 4     SAMSUNG S20 FE 5G (Cloud Lavender, 128 GB)  ₹36,499
# 5   SAMSUNG Galaxy A73 5G (Awesome Mint, 256 GB)  ₹49,990
# 6                           SAMSUNG Guru Music 2   ₹1,850
# 7                               SAMSUNG GT-E1215   ₹1,496
# 8                           SAMSUNG Guru Music 2   ₹2,068
# 9                           SAMSUNG Guru Music 2   ₹1,995
# 10                          SAMSUNG GURU MUSIC 2   ₹1,995
# 11                          SAMSUNG Guru Music 2   ₹1,995
# 12        SAMSUNG Galaxy A03 Core (Black, 32 GB)   ₹6,999
# 13         SAMSUNG Galaxy A03 Core (Blue, 32 GB)   ₹6,999
# 14               SAMSUNG Galaxy M02 (Red, 32 GB)   ₹9,199
# ...

# %%
mobile.to_csv("assignment.csv")
